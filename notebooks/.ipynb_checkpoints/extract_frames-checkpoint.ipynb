# %%
import cv2
import os

def extract_video(video_path, output_folder):

    # create folder
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # get video name
    video_name = os.path.basename(video_path).split('.')[0]
    cap = cv2.VideoCapture(video_path)

    frame_no = 0
    saved_no = 0

    while True:
        ret, frame = cap.read()

        if ret == False:
            break

        # save every 5th frame
        if frame_no % 5 == 0:
            filename = video_name + "_frame_" + str(frame_no) + ".jpg"
            cv2.imwrite(os.path.join(output_folder, filename), frame)
            saved_no += 1

        frame_no = frame_no + 1

    cap.release()

    print("DONE:", video_name, "Saved:", saved_no)

# %%
video_path = r"C:\Users\sasik\Desktop\ICT2403-road-damage-detection\data\videos\raw\alligator_cracking\alligator_01\aligatorCracking_1.mp4"
output_folder = r"C:\Users\sasik\Desktop\ICT2403-road-damage-detection\data\frames\extracted\alligator_cracking\alligator_01"
extract_video(video_path, output_folder)

video_path = r"C:\Users\sasik\Desktop\ICT2403-road-damage-detection\data\videos\raw\alligator_cracking\alligator_02\aligatorCracking_2.mp4"
output_folder = r"C:\Users\sasik\Desktop\ICT2403-road-damage-detection\data\frames\extracted\alligator_cracking\alligator_02"
extract_video(video_path, output_folder)

video_path = r"C:\Users\sasik\Desktop\ICT2403-road-damage-detection\data\videos\raw\alligator_cracking\alligator_03\aligatorCracking_3.mp4"
output_folder = r"C:\Users\sasik\Desktop\ICT2403-road-damage-detection\data\frames\extracted\alligator_cracking\alligator_03"
extract_video(video_path, output_folder)

video_path = r"C:\Users\sasik\Desktop\ICT2403-road-damage-detection\data\videos\raw\alligator_cracking\alligator_04\aligatorCracking_4.mp4"
output_folder = r"C:\Users\sasik\Desktop\ICT2403-road-damage-detection\data\frames\extracted\alligator_cracking\alligator_04"
extract_video(video_path, output_folder)

video_path = r"C:\Users\sasik\Desktop\ICT2403-road-damage-detection\data\videos\raw\alligator_cracking\alligator_05\aligatorCracking_5.mp4"
output_folder = r"C:\Users\sasik\Desktop\ICT2403-road-damage-detection\data\frames\extracted\alligator_cracking\alligator_05"
extract_video(video_path, output_folder)
# Out:
# DONE: aligatorCracking_1 Saved: 71
# DONE: aligatorCracking_2 Saved: 93
# DONE: aligatorCracking_3 Saved: 91
# DONE: aligatorCracking_4 Saved: 137
# DONE: aligatorCracking_5 Saved: 253

# %%
video_path = r"C:\Users\sasik\Desktop\ICT2403-road-damage-detection\data\videos\raw\raveling\raveling_01\raveling_1.mp4"
output_folder = r"C:\Users\sasik\Desktop\ICT2403-road-damage-detection\data\frames\extracted\raveling\raveling_01"
extract_video(video_path, output_folder)

video_path = r"C:\Users\sasik\Desktop\ICT2403-road-damage-detection\data\videos\raw\raveling\raveling_02\raveling_2.mp4"
output_folder = r"C:\Users\sasik\Desktop\ICT2403-road-damage-detection\data\frames\extracted\raveling\raveling_02"
extract_video(video_path, output_folder)
# Out:
# DONE: raveling_1 Saved: 556
# DONE: raveling_2 Saved: 329

# %%
video_path = r"C:\Users\sasik\Desktop\ICT2403-road-damage-detection\data\videos\raw\road_potholes\potholes_01\roadPotholes_1.mp4"
output_folder = r"C:\Users\sasik\Desktop\ICT2403-road-damage-detection\data\frames\extracted\road_potholes\potholes_01"
extract_video(video_path, output_folder)

video_path = r"C:\Users\sasik\Desktop\ICT2403-road-damage-detection\data\videos\raw\road_potholes\potholes_02\roadPotholes_2.mp4"
output_folder = r"C:\Users\sasik\Desktop\ICT2403-road-damage-detection\data\frames\extracted\road_potholes\potholes_02"
extract_video(video_path, output_folder)
# Out:
# DONE: roadPotholes_1 Saved: 67
# DONE: roadPotholes_2 Saved: 53

# %%
video_path = r"C:\Users\sasik\Desktop\ICT2403-road-damage-detection\data\videos\raw\transverse_cracking\transverse_01\transverseCracking_1.mp4"
output_folder = r"C:\Users\sasik\Desktop\ICT2403-road-damage-detection\data\frames\extracted\transverse_cracking\transverse_01"
extract_video(video_path, output_folder)

video_path = r"C:\Users\sasik\Desktop\ICT2403-road-damage-detection\data\videos\raw\transverse_cracking\transverse_02\transverseCracking_2.mp4"
output_folder = r"C:\Users\sasik\Desktop\ICT2403-road-damage-detection\data\frames\extracted\transverse_cracking\transverse_02"
extract_video(video_path, output_folder)

video_path = r"C:\Users\sasik\Desktop\ICT2403-road-damage-detection\data\videos\raw\transverse_cracking\transverse_03\transverseCracking_3.mp4"
output_folder = r"C:\Users\sasik\Desktop\ICT2403-road-damage-detection\data\frames\extracted\transverse_cracking\transverse_03"
extract_video(video_path, output_folder)
# Out:
# DONE: transverseCracking_1 Saved: 78
# DONE: transverseCracking_2 Saved: 178
# DONE: transverseCracking_3 Saved: 139
